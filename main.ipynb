# %%
import cv2

# %%
from deepface import DeepFace

# %%
img = cv2.imread('happy_female.jpeg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  3.67it/s]

# %%
predictions
# Out:
# {'emotion': {'angry': 3.8632344220167105e-14,
#   'disgust': 0.0,
#   'fear': 1.2930351810157368e-13,
#   'happy': 100.0,
#   'sad': 5.757905003483943e-10,
#   'surprise': 2.2696109880371296e-06,
#   'neutral': 1.4433492243190113e-13},
#  'dominant_emotion': 'happy',
#  'region': {'x': 280, 'y': 24, 'w': 148, 'h': 148},
#  'age': 28,
#  'gender': 'Man',
#  'race': {'asian': 0.01220062695172627,
#   'indian': 0.014376922028719456,
#   'black': 99.96531605513788,
#   'white': 2.9183316348787977e-05,
#   'middle eastern': 1.0936888314072269e-05,
#   'latino hispanic': 0.008062983150389905},
#  'dominant_race': 'black'}

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray,1.1,4)
for(x,y,w,h) in faces:
    cv2.rectangle(img, (x,y), (x+w, y+h), (0,255,0), 2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

#insert text on video
cv2.putText(img,
           predictions['dominant_emotion'],
            (0,50),
            font,1,
           (0,0,255),
           2,
           cv2.LINE_4) ;

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
